# %%
import pandas as pd
import matplotlib.pyplot as plt
#df = pd.read_csv('sheet 1.csv')
print(df.head())
data = {
    'Country': ['High income', 'Upper middle income', 'Lower middle income', 'Low income'],
    'Number of Countries': [81, 55, 53, 30]  # Example numbers, you would use actual data
}
df = pd.DataFrame(data)
plt.figure(figsize=(8, 6))
plt.bar(df['Country'], df['Number of Countries'], color='skyblue')
plt.xlabel('Income Classification')
plt.ylabel('Number of Countries')
plt.title('Distribution of Countries by Income Level')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
#                Country  Number of Countries
# 0          High income                   81
# 1  Upper middle income                   55
# 2  Lower middle income                   53
# 3           Low income                   30

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

data = pd.read_csv('sheet 2.csv')

# Create a bar plot to show the number of countries in each income group
plt.figure(figsize=(14, 8))
sns.countplot(y='IncomeGroup', data=data, palette='viridis')
plt.title('Number of Countries by Income Group')
plt.xlabel('Number of Countries')
plt.ylabel('Income Group')
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Get population data for 2022
data_2022 = data[['Country Name', '2022']].sort_values(by='2022', ascending=False).head(10)

# Plot top countries by population in 2023
plt.figure(figsize=(12, 6))
plt.barh(data_2022['Country Name'], data_2022['2022'], color='skyblue')
plt.title('Top 10 Countries by Population in 2022')
plt.xlabel('Population')
plt.ylabel('Country')
plt.tight_layout()
plt.show()
